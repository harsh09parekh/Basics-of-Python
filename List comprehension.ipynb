# %%
x = [1, 2, 40]
print(x)
print([i for i in x])
# Out:
# [1, 2, 40]
# [1, 2, 40]

# %%
import math
print([math.sqrt(i) for i in [1,2,3,4]])
# Out:
# [1.0, 1.4142135623730951, 1.7320508075688772, 2.0]

# %%
print([i*i for i in [1,2,3,4]])
# Out:
# [1, 4, 9, 16]

# %%
print([i for i in [10,2,5,7,8,54,50,99] if i%2==0])
# Out:
# [10, 2, 8, 54, 50]

# %%
print([i for i in [10,2,5,7,8,54,50,99] if i%2!=0])
# Out:
# [5, 7, 99]

# %%
print([i for i in [-2,5,-3,6,7,-9,-12,13,20] if i>0])
# Out:
# [5, 6, 7, 13, 20]

# %%
print([str(i) for i in [1,3,7,9,11,13,15,17,19,21,25,28,30,33,36] if i%3==0])
# Out:
# ['3', '9', '15', '21', '30', '33', '36']

# %%
sent = 'the number of active cases in the country stands at 133632'
print([len(i) for i in sent.split() if i != 'the'])
# Out:
# [6, 2, 6, 5, 2, 7, 6, 2, 6]

# %%
print([each for each in 'Happy Anniversary' if each in 'aAeEiIoOuU'])
# Out:
# ['a', 'A', 'i', 'e', 'a']

# %%
print([i*2 if i%2==0 else -i for i in [1,2,3,4,5] ])
# Out:
# [-1, 4, -3, 8, -5]

# %%
sent = 'the quick brown fox jumps over the lazy dog'
print([i.replace('a','1').replace('y','1') for i in sent.split()],)
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'l1z1', 'dog']

# %%
print(i for i in range(1,1001) if i%7==0)
# Out:
# <generator object <genexpr> at 0x003C7B70>

# %%
print(i for i in range(1,1001) if '3' in i.str())
# Out:
# <generator object <genexpr> at 0x003C7F00>

# %%
space = [s for s in 'the quick brown fox jumps over the lazy dog' if s == ' ']
print(len(space))
# Out:
# 8

# %%
string = 'the quick brown fox jumps over the lazy dog'
new_str = [string.replace(i, '') for i in string.lower() if i in 'aeiou']
print(new_str)
# Out:
# ['th quick brown fox jumps ovr th lazy dog', 'the qick brown fox jmps over the lazy dog', 'the quck brown fox jumps over the lazy dog', 'the quick brwn fx jumps ver the lazy dg', 'the quick brwn fx jumps ver the lazy dg', 'the qick brown fox jmps over the lazy dog', 'the quick brwn fx jumps ver the lazy dg', 'th quick brown fox jumps ovr th lazy dog', 'th quick brown fox jumps ovr th lazy dog', 'the quick brown fox jumps over the lzy dog', 'the quick brwn fx jumps ver the lazy dg']

# %%
string = 'the quick brown fox jumps over the lazy dog'
print([i for i in string.split() if len(i)<4])
# Out:
# ['the', 'fox', 'the', 'dog']

# %%
strings = 'the quick brown fox jumps over the lazy dog'
len_strings = {name:len(name) for name in strings.split()}
print(len_strings)
# Out:
# {'lazy': 4, 'dog': 3, 'the': 3, 'brown': 5, 'quick': 5, 'jumps': 5, 'over': 4, 'fox': 3}

# %%
uniq_num = [num for num in range(1,1001) if [div for div in range(2,10) if num%div == 0]]
print(uniq_num)
# Out:
# [2, 3, 4, 4, 5, 6, 6, 6, 7, 8, 8, 8, 9, 9, 10, 10, 12, 12, 12, 12, 14, 14, 15, 15, 16, 16, 16, 18, 18, 18, 18, 20, 20, 20, 21, 21, 22, 24, 24, 24, 24, 24, 25, 26, 27, 27, 28, 28, 28, 30, 30, 30, 30, 32, 32, 32, 33, 34, 35, 35, 36, 36, 36, 36, 36, 38, 39, 40, 40, 40, 40, 42, 42, 42, 42, 44, 44, 45, 45, 45, 46, 48, 48, 48, 48, 48, 49, 50, 50, 51, 52, 52, 54, 54, 54, 54, 55, 56, 56, 56, 56, 57, 58, 60, 60, 60, 60, 60, 62, 63, 63, 63, 64, 64, 64, 65, 66, 66, 66, 68, 68, 69, 70, 70, 70, 72, 72, 72, 72, 72, 72, 74, 75, 75, 76, 76, 77, 78, 78, 78, 80, 80, 80, 80, 81, 81, 82, 84, 84, 84, 84, 84, 85, 86, 87, 88, 88, 88, 90, 90, 90, 90, 90, 91, 92, 92, 93, 94, 95, 96, 96, 96, 96, 96, 98, 98, 99, 99, 100, 100, 100, 102, 102, 102, 104, 104, 104, 105, 105, 105, 106, 108, 108, 108, 108, 108, 110, 110, 111, 112, 112, 112, 112, 114, 114, 114, 115, 116, 116, 117, 117, 118, 119, 120, 120, 120, 120, 120, 120, 122, 123, 124, 124, 125, 126, 126, 126, 126, 126, 128, 128, 128, 129, 130, 130, 132, 132, 132,
# ...

# %%
uniq = [divisor for divisor in range(1,1001) if number % divisor == 0]
print(uniq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5a71a401b816> in <module>()
# ----> 1 uniq = [divisor for divisor in range(1,1001) if number % divisor == 0]
#       2 print(uniq)
#
# <ipython-input-15-5a71a401b816> in <listcomp>(.0)
# ----> 1 uniq = [divisor for divisor in range(1,1001) if number % divisor == 0]
#       2 print(uniq)
#
# NameError: name 'number' is not defined
